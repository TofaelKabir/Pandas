# %%
import pandas as pd
import numpy as np
import random

# %%
df = pd. read_csv('4.csv')

# %%
df
# Out:
#           Column       Name  Age Nationality Student  \
# 0     Respondent  Tofael483   23         USA       Y
# 1     MainBranch  Tofael484   24          UK       N
# 2       Hobbyist  Tofael485   25     Germany     NaN
# 3    OpenSourcer  Tofael486   26       China     NaN
# 4     OpenSource  Tofael487   27      France       N
# ..           ...        ...  ...         ...     ...
# 80     Sexuality  Tofael563   52      France     NaN
# 81     Ethnicity  Tofael564   53  Bangladesh     NaN
# 82    Dependents  Tofael565   54       India     NaN
# 83  SurveyLength  Tofael566   55    Pakistan       Y
# 84    SurveyEase  Tofael567   56     Morocco       N
#
#                                          QuestionText
# 0   Randomized respondent ID number (not in order ...
# 1   Which of the following options best describes ...
# 2                             Do you code as a hobby?
# 3         How often do you contribute to open source?
# ...

# %%
bangladeshi = df[df['Nationality'] == 'Bangladesh']

# %%
bangladeshi
# Out:
#                 Column       Name  Age Nationality Student  \
# 5           Employment  Tofael488   28  Bangladesh       N
# 16           CareerSat  Tofael499   50  Bangladesh       N
# 24            FizzBuzz  Tofael507   47  Bangladesh       N
# 35          WorkRemote  Tofael518   58  Bangladesh       N
# 43  LanguageWorkedWith  Tofael526   36  Bangladesh       Y
# 54               OpSys  Tofael537   77  Bangladesh       N
# 62        Extraversion  Tofael545   56  Bangladesh     NaN
# 73            EntTeams  Tofael556   96  Bangladesh       Y
# 81           Ethnicity  Tofael564   53  Bangladesh     NaN
#
#                                          QuestionText
# 5   Which of the following best describes your cur...
# 16  Overall, how satisfied are you with your caree...
# 24  Have you ever been asked to solve FizzBuzz in ...
# 35                    How often do you work remotely?
# 43  Which of the following programming, scripting,...
# ...

# %%
others = df[df['Nationality'] != 'Bangladesh']
# not equal

# %%
others
# Out:
#           Column       Name  Age Nationality Student  \
# 0     Respondent  Tofael483   23         USA       Y
# 1     MainBranch  Tofael484   24          UK       N
# 2       Hobbyist  Tofael485   25     Germany     NaN
# 3    OpenSourcer  Tofael486   26       China     NaN
# 4     OpenSource  Tofael487   27      France       N
# ..           ...        ...  ...         ...     ...
# 79         Trans  Tofael562   51       China       N
# 80     Sexuality  Tofael563   52      France     NaN
# 82    Dependents  Tofael565   54       India     NaN
# 83  SurveyLength  Tofael566   55    Pakistan       Y
# 84    SurveyEase  Tofael567   56     Morocco       N
#
#                                          QuestionText
# 0   Randomized respondent ID number (not in order ...
# 1   Which of the following options best describes ...
# 2                             Do you code as a hobby?
# 3         How often do you contribute to open source?
# ...

# %%
student = df[df['Student'] == 'Y']

# %%
student
# Out:
#                 Column       Name  Age    Nationality Student  \
# 0           Respondent  Tofael483   23            USA       Y
# 6              Country  Tofael489   29          India       Y
# 8              EdLevel  Tofael491   49        Morocco       Y
# 11             OrgSize  Tofael494   52            USA       Y
# 12             DevType  Tofael495   53             UK       Y
# 13           YearsCode  Tofael496   54        Germany       Y
# 15        YearsCodePro  Tofael498   49         France       Y
# 21             JobSeek  Tofael504   44        Germany       Y
# 23             LastInt  Tofael506   46         France       Y
# 26        ResumeUpdate  Tofael509   49       Pakistan       Y
# 27      CurrencySymbol  Tofael510   50        Morocco       Y
# 28        CurrencyDesc  Tofael511   51  Saufdi Arabia       Y
# 30            CompFreq  Tofael513   53            USA       Y
# 36             WorkLoc  Tofael519   59          India       Y
# ...

# %%
Notstudent = df[df['Student'] != 'Y']

# %%
Notstudent
# Out:
#                     Column       Name  Age    Nationality Student  \
# 1               MainBranch  Tofael484   24             UK       N
# 2                 Hobbyist  Tofael485   25        Germany     NaN
# 3              OpenSourcer  Tofael486   26          China     NaN
# 4               OpenSource  Tofael487   27         France       N
# 5               Employment  Tofael488   28     Bangladesh       N
# 7                  Student  Tofael490   48       Pakistan       N
# 9           UndergradMajor  Tofael492   50  Saufdi Arabia       N
# 10                EduOther  Tofael493   51         Canada     NaN
# 14              Age1stCode  Tofael497   48          China       N
# 16               CareerSat  Tofael499   50     Bangladesh       N
# 17                  JobSat  Tofael500   51          India       N
# 18                MgrIdiot  Tofael501   52       Pakistan     NaN
# 19                MgrMoney  Tofael502   53            USA     NaN
# ...

# %%
df1 = df[(df['Nationality'] == 'Bangladesh') & (df['Age'] != '23')]
# & = and | = or
# Out:
# /Users/mohammadsharkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
df1
# Out:
#                 Column       Name  Age Nationality Student  \
# 5           Employment  Tofael488   28  Bangladesh       N
# 16           CareerSat  Tofael499   50  Bangladesh       N
# 24            FizzBuzz  Tofael507   47  Bangladesh       N
# 35          WorkRemote  Tofael518   58  Bangladesh       N
# 43  LanguageWorkedWith  Tofael526   36  Bangladesh       Y
# 54               OpSys  Tofael537   77  Bangladesh       N
# 62        Extraversion  Tofael545   56  Bangladesh     NaN
# 73            EntTeams  Tofael556   96  Bangladesh       Y
# 81           Ethnicity  Tofael564   53  Bangladesh     NaN
#
#                                          QuestionText
# 5   Which of the following best describes your cur...
# 16  Overall, how satisfied are you with your caree...
# 24  Have you ever been asked to solve FizzBuzz in ...
# 35                    How often do you work remotely?
# 43  Which of the following programming, scripting,...
# ...

# %%
df1 = df[(df['Nationality'] == 'Bangladesh') | (df['Student'] == 'Y')]

# %%
df1
# Out:
#                 Column       Name  Age    Nationality Student  \
# 0           Respondent  Tofael483   23            USA       Y
# 5           Employment  Tofael488   28     Bangladesh       N
# 6              Country  Tofael489   29          India       Y
# 8              EdLevel  Tofael491   49        Morocco       Y
# 11             OrgSize  Tofael494   52            USA       Y
# 12             DevType  Tofael495   53             UK       Y
# 13           YearsCode  Tofael496   54        Germany       Y
# 15        YearsCodePro  Tofael498   49         France       Y
# 16           CareerSat  Tofael499   50     Bangladesh       N
# 21             JobSeek  Tofael504   44        Germany       Y
# 23             LastInt  Tofael506   46         France       Y
# 24            FizzBuzz  Tofael507   47     Bangladesh       N
# 26        ResumeUpdate  Tofael509   49       Pakistan       Y
# 27      CurrencySymbol  Tofael510   50        Morocco       Y
# ...

# %%
df1 = df[(df['Nationality'] != 'Bangladesh') & (df['Age'] != '23') | (df['Student'] == 'Y')]

# %%
df1
# Out:
#           Column       Name  Age Nationality Student  \
# 0     Respondent  Tofael483   23         USA       Y
# 1     MainBranch  Tofael484   24          UK       N
# 2       Hobbyist  Tofael485   25     Germany     NaN
# 3    OpenSourcer  Tofael486   26       China     NaN
# 4     OpenSource  Tofael487   27      France       N
# ..           ...        ...  ...         ...     ...
# 79         Trans  Tofael562   51       China       N
# 80     Sexuality  Tofael563   52      France     NaN
# 82    Dependents  Tofael565   54       India     NaN
# 83  SurveyLength  Tofael566   55    Pakistan       Y
# 84    SurveyEase  Tofael567   56     Morocco       N
#
#                                          QuestionText
# 0   Randomized respondent ID number (not in order ...
# 1   Which of the following options best describes ...
# 2                             Do you code as a hobby?
# 3         How often do you contribute to open source?
# ...

# %%
df1 = df[(df['Age']> 33) & (df['Age']<45)]

# %%
df1
# Out:
#                     Column       Name  Age    Nationality Student  \
# 21                 JobSeek  Tofael504   44        Germany       Y
# 41             PurchaseHow  Tofael524   34          China     NaN
# 42            PurchaseWhat  Tofael525   35         France       Y
# 43      LanguageWorkedWith  Tofael526   36     Bangladesh       Y
# 44  LanguageDesireNextYear  Tofael527   37          India       N
# 45      DatabaseWorkedWith  Tofael528   38       Pakistan       Y
# 46  DatabaseDesireNextYear  Tofael529   39        Morocco       N
# 47      PlatformWorkedWith  Tofael530   40  Saufdi Arabia       N
# 48  PlatformDesireNextYear  Tofael531   41         Canada       N
# 49      WebFrameWorkedWith  Tofael532   42            USA       N
# 50  WebFrameDesireNextYear  Tofael533   43             UK       N
# 58              BetterLife  Tofael541   34             UK       Y
# 59                ITperson  Tofael542   35        Germany       N
# ...

# %%
# group by value

# %%
df1
# Out:
#           Column       Name  Age Nationality Student  \
# 0     Respondent  Tofael483   23         USA       Y
# 1     MainBranch  Tofael484   24          UK       N
# 2       Hobbyist  Tofael485   25     Germany     NaN
# 3    OpenSourcer  Tofael486   26       China     NaN
# 4     OpenSource  Tofael487   27      France       N
# ..           ...        ...  ...         ...     ...
# 80     Sexuality  Tofael563   52      France     NaN
# 81     Ethnicity  Tofael564   53  Bangladesh     NaN
# 82    Dependents  Tofael565   54       India     NaN
# 83  SurveyLength  Tofael566   55    Pakistan       Y
# 84    SurveyEase  Tofael567   56     Morocco       N
#
#                                          QuestionText
# 0   Randomized respondent ID number (not in order ...
# 1   Which of the following options best describes ...
# 2                             Do you code as a hobby?
# 3         How often do you contribute to open source?
# ...

# %%
df
# Out:
#           Column       Name  Age Nationality Student  \
# 0     Respondent  Tofael483   23         USA       Y
# 1     MainBranch  Tofael484   24          UK       N
# 2       Hobbyist  Tofael485   25     Germany     NaN
# 3    OpenSourcer  Tofael486   26       China     NaN
# 4     OpenSource  Tofael487   27      France       N
# ..           ...        ...  ...         ...     ...
# 80     Sexuality  Tofael563   52      France     NaN
# 81     Ethnicity  Tofael564   53  Bangladesh     NaN
# 82    Dependents  Tofael565   54       India     NaN
# 83  SurveyLength  Tofael566   55    Pakistan       Y
# 84    SurveyEase  Tofael567   56     Morocco       N
#
#                                          QuestionText
# 0   Randomized respondent ID number (not in order ...
# 1   Which of the following options best describes ...
# 2                             Do you code as a hobby?
# 3         How often do you contribute to open source?
# ...

# %%
# creating a list name 'a'
a = []
for i in range (0, 85):
    a.append(random.randint(0,7))

# %%
df ['Children'] = a

# %%
df
# Out:
#           Column       Name  Age Nationality Student  \
# 0     Respondent  Tofael483   23         USA       Y
# 1     MainBranch  Tofael484   24          UK       N
# 2       Hobbyist  Tofael485   25     Germany     NaN
# 3    OpenSourcer  Tofael486   26       China     NaN
# 4     OpenSource  Tofael487   27      France       N
# ..           ...        ...  ...         ...     ...
# 80     Sexuality  Tofael563   52      France     NaN
# 81     Ethnicity  Tofael564   53  Bangladesh     NaN
# 82    Dependents  Tofael565   54       India     NaN
# 83  SurveyLength  Tofael566   55    Pakistan       Y
# 84    SurveyEase  Tofael567   56     Morocco       N
#
#                                          QuestionText  children  Children
# 0   Randomized respondent ID number (not in order ...         5         4
# 1   Which of the following options best describes ...         5         3
# 2                             Do you code as a hobby?         1         5
# ...

# %%
df[df['Children'] == 4]
# Out:
#                 Column       Name  Age Nationality Student  \
# 0           Respondent  Tofael483   23         USA       Y
# 15        YearsCodePro  Tofael498   49      France       Y
# 22        LastHireDate  Tofael505   45       China       N
# 23             LastInt  Tofael506   46      France       Y
# 26        ResumeUpdate  Tofael509   49    Pakistan       Y
# 33            WorkPlan  Tofael516   56       China       N
# 51  MiscTechWorkedWith  Tofael534   74     Germany       Y
# 55          Containers  Tofael538   78       India       N
# 57        BlockchainIs  Tofael540   80         USA       Y
# 60               OffOn  Tofael543   36       China       Y
# 71          SOPartFreq  Tofael554   94       China       Y
# 83        SurveyLength  Tofael566   55    Pakistan       Y
#
#                                          QuestionText  children  Children
# 0   Randomized respondent ID number (not in order ...         5         4
# ...

# %%
dfN = df[['Column', 'Name', 'Age', 'Nationality', 'Student', 'QuestionText', 'Children']]

# %%
dfN
# Out:
#           Column       Name  Age Nationality Student  \
# 0     Respondent  Tofael483   23         USA       Y
# 1     MainBranch  Tofael484   24          UK       N
# 2       Hobbyist  Tofael485   25     Germany     NaN
# 3    OpenSourcer  Tofael486   26       China     NaN
# 4     OpenSource  Tofael487   27      France       N
# ..           ...        ...  ...         ...     ...
# 80     Sexuality  Tofael563   52      France     NaN
# 81     Ethnicity  Tofael564   53  Bangladesh     NaN
# 82    Dependents  Tofael565   54       India     NaN
# 83  SurveyLength  Tofael566   55    Pakistan       Y
# 84    SurveyEase  Tofael567   56     Morocco       N
#
#                                          QuestionText  Children
# 0   Randomized respondent ID number (not in order ...         4
# 1   Which of the following options best describes ...         3
# 2                             Do you code as a hobby?         5
# 3         How often do you contribute to open source?         7
# ...

# %%
dfN1=dfN[dfN['Children'] == 4]

# %%
dfN1
# Out:
#                 Column       Name  Age Nationality Student  \
# 0           Respondent  Tofael483   23         USA       Y
# 15        YearsCodePro  Tofael498   49      France       Y
# 22        LastHireDate  Tofael505   45       China       N
# 23             LastInt  Tofael506   46      France       Y
# 26        ResumeUpdate  Tofael509   49    Pakistan       Y
# 33            WorkPlan  Tofael516   56       China       N
# 51  MiscTechWorkedWith  Tofael534   74     Germany       Y
# 55          Containers  Tofael538   78       India       N
# 57        BlockchainIs  Tofael540   80         USA       Y
# 60               OffOn  Tofael543   36       China       Y
# 71          SOPartFreq  Tofael554   94       China       Y
# 83        SurveyLength  Tofael566   55    Pakistan       Y
#
#                                          QuestionText  Children
# 0   Randomized respondent ID number (not in order ...         4
# 15  How many years have you coded professionally (...         4
# ...

# %%
dfN1.shape
# Out:
# (12, 7)

# %%
dfN1.shape[1]
# 0 represent rows, 1 represent columns
# Out:
# 7

# %%
dfN1.shape[0]
# Out:
# 12

# %%
h = dfN.groupby('Children')
# h is not printing

# %%
for i in h:
    print(i)
# printed the whole dataframe by group, all the columns are selected, specially the questionText taking wide space
# Out:
# (0,                     Column       Name  Age    Nationality Student  \
# 8                  EdLevel  Tofael491   49        Morocco       Y
# 10                EduOther  Tofael493   51         Canada     NaN
# 12                 DevType  Tofael495   53             UK       Y
# 17                  JobSat  Tofael500   51          India       N
# 19                MgrMoney  Tofael502   53            USA     NaN
# 28            CurrencyDesc  Tofael511   51  Saufdi Arabia       Y
# 31           ConvertedComp  Tofael514   54             UK     NaN
# 32             WorkWeekHrs  Tofael515   55        Germany       N
# 44  LanguageDesireNextYear  Tofael527   37          India       N
# 59                ITperson  Tofael542   35        Germany       N
# 63              ScreenName  Tofael546   65          India     NaN
# 68             SOTimeSaved  Tofael551   91            USA       Y
# 69           SOHowMuchTime  Tofael552   92             UK       N
# ...

# %%
# so for loop is not the best way to loook
h.get_group(5)
#similarly we can choose any children number
# Out:
#            Column       Name  Age Nationality Student  \
# 2        Hobbyist  Tofael485   25     Germany     NaN
# 7         Student  Tofael490   48    Pakistan       N
# 13      YearsCode  Tofael496   54     Germany       Y
# 20        MgrWant  Tofael503   54          UK       N
# 35     WorkRemote  Tofael518   58  Bangladesh       N
# 37         ImpSyn  Tofael520   30    Pakistan       N
# 40      UnitTests  Tofael523   33     Germany     NaN
# 56  BlockchainOrg  Tofael539   79    Pakistan       Y
# 65    SOVisitFreq  Tofael548   88     Morocco       N
# 74         SOComm  Tofael557   97       India       N
# 80      Sexuality  Tofael563   52      France     NaN
#
#                                          QuestionText  Children
# 2                             Do you code as a hobby?         5
# 7   Are you currently enrolled in a formal, degree...         5
# 13  Including any education, how many years have y...         5
# ...

# %%
# creating a list name 'b'
b = []
for i in range (0, 85):
    b.append(random.randint(0,4))

# %%
dfN['Grade'] = b

# %%
dfN
# Out:
#           Column       Name  Age Nationality Student  \
# 0     Respondent  Tofael483   23         USA       Y
# 1     MainBranch  Tofael484   24          UK       N
# 2       Hobbyist  Tofael485   25     Germany     NaN
# 3    OpenSourcer  Tofael486   26       China     NaN
# 4     OpenSource  Tofael487   27      France       N
# ..           ...        ...  ...         ...     ...
# 80     Sexuality  Tofael563   52      France     NaN
# 81     Ethnicity  Tofael564   53  Bangladesh     NaN
# 82    Dependents  Tofael565   54       India     NaN
# 83  SurveyLength  Tofael566   55    Pakistan       Y
# 84    SurveyEase  Tofael567   56     Morocco       N
#
#                                          QuestionText  Children  Boys  Grade
# 0   Randomized respondent ID number (not in order ...         4     4      1
# 1   Which of the following options best describes ...         3     2      1
# 2                             Do you code as a hobby?         5     4      4
# ...

# %%
h = dfN[['Column', 'Name', 'Age', 'Nationality', 'Student', 'QuestionText', 'Children', 'Grade' ]]

# %%
h
# Out:
#           Column       Name  Age Nationality Student  \
# 0     Respondent  Tofael483   23         USA       Y
# 1     MainBranch  Tofael484   24          UK       N
# 2       Hobbyist  Tofael485   25     Germany     NaN
# 3    OpenSourcer  Tofael486   26       China     NaN
# 4     OpenSource  Tofael487   27      France       N
# ..           ...        ...  ...         ...     ...
# 80     Sexuality  Tofael563   52      France     NaN
# 81     Ethnicity  Tofael564   53  Bangladesh     NaN
# 82    Dependents  Tofael565   54       India     NaN
# 83  SurveyLength  Tofael566   55    Pakistan       Y
# 84    SurveyEase  Tofael567   56     Morocco       N
#
#                                          QuestionText  Children  Grade
# 0   Randomized respondent ID number (not in order ...         4      1
# 1   Which of the following options best describes ...         3      1
# 2                             Do you code as a hobby?         5      4
# ...

# %%
newh = h.groupby(['Children', 'Grade'])

# %%
newh

# %%
for i in newh:
    print (i)
# Out:
# ((0, 0),                     Column       Name  Age Nationality Student  \
# 44  LanguageDesireNextYear  Tofael527   37       India       N
# 63              ScreenName  Tofael546   65       India     NaN
# 68             SOTimeSaved  Tofael551   91         USA       Y
# 73                EntTeams  Tofael556   96  Bangladesh       Y
# 84              SurveyEase  Tofael567   56     Morocco       N
#
#                                          QuestionText  Children  Grade
# 44  Which of the following programming, scripting,...         0      0
# 63                               What do you call it?         0      0
# 68  Think back to the last time you solved a codin...         0      0
# 73  Have you ever used Stack Overflow for Enterpri...         0      0
# 84  How easy or difficult was this survey to compl...         0      0  )
# ((0, 1),            Column       Name  Age Nationality Student  \
# 10       EduOther  Tofael493   51      Canada     NaN
# ...

# %%
newh.get_group((4, 3))
# a group who have 4 children with grade 3
# Out:
#           Column       Name  Age Nationality Student  \
# 23       LastInt  Tofael506   46      France       Y
# 83  SurveyLength  Tofael566   55    Pakistan       Y
#
#                                          QuestionText  Children  Grade
# 23  In your most recent successful job interview (...         4      3
# 83  How do you feel about the length of the survey...         4      3

# %%
newh = h.groupby(['Children', 'Grade']).size()

# %%
newh
# see the value below and understand the change
# Out:
# Children  Grade
# 0         0        5
#           1        5
#           2        1
#           3        3
#           4        1
# 1         2        5
#           3        5
#           4        1
# 2         1        6
#           2        1
#           3        2
#           4        1
# 3         0        1
#           1        2
#           2        1
#           3        3
#           4        1
# 4         0        3
#           1        2
#           2        3
#           3        2
#           4        2
# 5         0        2
#           1        1
#           2        2
#           3        2
#           4        4
# 6         1        3
#           2        1
#           3        1
#           4        4
# 7         0        2
#           1        3
#           2        1
#           3        2
#           4        1
# dtype: int64

# %%
newh = h.groupby(['Children', 'Grade']).count()
# same but show also other column with same data

# %%
newh
# Out:
#                 Column  Name  Age  Nationality  Student  QuestionText
# Children Grade
# 0        0           5     5    5            5        4             5
#          1           5     5    5            5        2             5
#          2           1     1    1            1        1             1
#          3           3     3    3            3        3             3
#          4           1     1    1            1        1             1
# 1        2           5     5    5            5        5             5
#          3           5     5    5            5        5             5
#          4           1     1    1            1        0             1
# 2        1           6     6    6            6        6             6
#          2           1     1    1            1        1             1
#          3           2     2    2            2        0             2
#          4           1     1    1            1        1             1
# ...

# %%
newh = h.groupby(['Children']).get_group((0))

# %%
newh
# Out:
#                     Column       Name  Age    Nationality Student  \
# 8                  EdLevel  Tofael491   49        Morocco       Y
# 10                EduOther  Tofael493   51         Canada     NaN
# 12                 DevType  Tofael495   53             UK       Y
# 17                  JobSat  Tofael500   51          India       N
# 19                MgrMoney  Tofael502   53            USA     NaN
# 28            CurrencyDesc  Tofael511   51  Saufdi Arabia       Y
# 31           ConvertedComp  Tofael514   54             UK     NaN
# 32             WorkWeekHrs  Tofael515   55        Germany       N
# 44  LanguageDesireNextYear  Tofael527   37          India       N
# 59                ITperson  Tofael542   35        Germany       N
# 63              ScreenName  Tofael546   65          India     NaN
# 68             SOTimeSaved  Tofael551   91            USA       Y
# 69           SOHowMuchTime  Tofael552   92             UK       N
# ...

# %%
newh = h.groupby(['Children'])['Age', 'Grade'].agg(['mean', 'max', 'min'])
#compared with Children only
# what will happen if ['Age', 'Grade'] is not used, need to check
# Out:
# <ipython-input-153-60c4ed5c5e9b>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   newh = h.groupby(['Children'])['Age', 'Grade'].agg(['mean', 'max', 'min'])

# %%
newh
# Out:
#                 Age             Grade
#                mean max min      mean max min
# Children
# 0         59.266667  96  35  1.333333   4   0
# 1         64.727273  98  27  2.636364   4   2
# 2         47.000000  90  34  1.800000   4   1
# 3         36.000000  52  24  2.125000   4   0
# 4         57.083333  94  23  1.833333   4   0
# 5         56.181818  97  25  2.454545   4   0
# 6         49.888889  76  34  2.666667   4   1
# 7         49.666667  75  26  1.666667   4   0

# %%
newh = h.groupby(['Children', 'Grade']).get_group((0,1))

# %%
newh
# Out:
#            Column       Name  Age Nationality Student  \
# 10       EduOther  Tofael493   51      Canada     NaN
# 17         JobSat  Tofael500   51       India       N
# 19       MgrMoney  Tofael502   53         USA     NaN
# 31  ConvertedComp  Tofael514   54          UK     NaN
# 32    WorkWeekHrs  Tofael515   55     Germany       N
#
#                                          QuestionText  Children  Grade
# 10  Which of the following types of non-degree edu...         0      1
# 17  How satisfied are you with your current job? (...         0      1
# 19  Do you believe that you need to be a manager t...         0      1
# 31  Salary converted to annual USD salaries using ...         0      1
# 32   On average, how many hours per week do you work?         0      1

# %%
newh = h.groupby(['Children', 'Grade']).agg(['mean', 'max', 'min'])
#compared with Children and grade

# %%
newh
# Out:
#                       Age
#                      mean max min
# Children Grade
# 0        0      69.000000  96  37
#          1      52.800000  55  51
#          2      92.000000  92  92
#          3      45.666667  53  35
#          4      51.000000  51  51
# 1        2      59.800000  95  27
#          3      71.800000  98  31
#          4      54.000000  54  54
# 2        1      46.166667  90  34
#          2      39.000000  39  39
#          3      52.500000  53  52
#          4      49.000000  49  49
# 3        0      48.000000  48  48
#          1      29.000000  34  24
#          2      32.000000  32  32
#          3      40.666667  52  29
#          4      28.000000  28  28
# 4        0      45.666667  56  36
#          1      48.500000  74  23
#          2      59.333333  80  49
#          3      50.500000  55  46
#          4      86.000000  94  78
# 5        0      77.500000  97  58
#          1      52.000000  52  52
#          2      71.000000  88  54
# ...

# %%
newh = h.groupby(['Children', 'Grade']).Nationality.count()
# just only for Nationality

# %%
newh
# Out:
# Children  Grade
# 0         0        5
#           1        5
#           2        1
#           3        3
#           4        1
# 1         2        5
#           3        5
#           4        1
# 2         1        6
#           2        1
#           3        2
#           4        1
# 3         0        1
#           1        2
#           2        1
#           3        3
#           4        1
# 4         0        3
#           1        2
#           2        3
#           3        2
#           4        2
# 5         0        2
#           1        1
#           2        2
#           3        2
#           4        4
# 6         1        3
#           2        1
#           3        1
#           4        4
# 7         0        2
#           1        3
#           2        1
#           3        2
#           4        1
# Name: Nationality, dtype: int64

# %%
# not working
# newh = h.groupby(['Children', 'Grade']).['Nationality', 'Age'].count()
# for Nationality and Age

# %%
# https://www.youtube.com/watch?v=ZyhVh-qRZPA&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS
# corey schafer above
# cj dojo below for python
# https://www.youtube.com/watch?v=Z1Yd7upQsXY&list=PLBZBJbE_rGRWeh5mIBhD-hhDwSEDxogDg
